# %%
import pandas as pd

# %%
df = pd.read_csv("/opt/predii/isha/enginuity/results/data-13/table_data/page_194/page_194.csv",sep="\t")

# %%
df
# Out:
#     (1) ITEM NO (2) SMR CODE       (3) NSN (4) CAGEC (5) PART NUMBER  \
# 0           NaN          NaN           NaN       NaN             NaN
# 1          17.0        PFHZZ  5.360013e+12     53867   1 414 618 030
# 2           NaN          NaN           NaN       NaN             NaN
# 3          18.0        PFHZZ  5.340013e+12     53867   1 410 505 015
# 4           NaN          NaN           NaN       NaN             NaN
# 5          19.0        PFHZZ  2.910013e+12     53867   1 410 422 031
# 6           NaN          NaN           NaN       NaN             NaN
# 7          20.0        PFHZZ  5.331013e+12     53867      1410210503
# 8           NaN          NaN           NaN       NaN             NaN
# 9           NaN          NaN           NaN       NaN             NaN
# 10         21.0        PFHZZ  5.365013e+12     53867   1 410 290 005
# 11          NaN          NaN           NaN       NaN             NaN
# 12          NaN          NaN           NaN       NaN             NaN
# ...

# %%
cols = ["FIG_NO", "ITEM_NO", "SMR_CODE", "STOCK_NUMBER", "CAGE", "PART_NUMBER", "DESCRIPTION", "UM", "QTY"]

df = pd.read_csv(
    "/opt/predii/tilak/enginuity/tsv_output/data-2/page_98.tsv",
    sep="\t",
    skiprows=7,
    names=cols
)

# %%
df
# Out:
#     FIG_NO  ITEM_NO SMR_CODE       STOCK_NUMBER   CAGE  PART_NUMBER  \
# 0       32       62    KFHZZ              . . .  72582      5150372
# 1       32       62    KFHZZ              . . .  72582      5150855
# 2       32       62    KFHZZ              . . .  24617      5150856
# 3       32       62    KFHZZ              . . .  72582      5153938
# 4       32       63    PFHZZ  3020-005-591-8122  72582      5196321
# 5       32       64    XAHZZ                NaN  72582      5117079
# 6       32       65    XAHZZ                NaN  72582      5125849
# 7       32       66    PFHZZ   5365-01-059-3438  72582      5146049
# 8       32       67    PAHZZ   5305-01-058-4512  72582      9409060
# 9       32       68    PAHZZ   5305-01-165-3265  72582      5147149
# 10      32       69    PAFZZ   5330-01-166-1020  72582      8923959
# 11      32       70    PAFZZ   4820-01-270-6456  72582      8927187
#
#                                    DESCRIPTION  UM  QTY
# ...
